# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from numpy.random import default_rng

# %%
df = pandas.read_csv('data_and_notebook_A3/bm.csv')
df = df.dropna()
df
# Out:
#        6.7593   2.9984  0
# 0    -2.62890  3.97460  0
# 1     0.88878 -1.43350  1
# 2    -2.03500 -3.74210  0
# 3    -7.43160  0.86322  0
# 4     1.04550 -2.99510  0
# ...       ...      ... ..
# 9994  5.01880 -0.28495  1
# 9995  7.23240 -0.24904  0
# 9996 -2.03320 -0.44094  1
# 9997 -4.49600 -1.99200  1
# 9998  2.50910  1.92650  0
#
# [9999 rows x 3 columns]

# %%
df.columns = ['A', 'B', 'C']
#df.loc[len(df)] = [6.7593, 2.9984, 0]
#df
new_record = pd.DataFrame([[6.7593, 2.9984, 0]], columns=df.columns)
df = pd.concat([new_record, df], ignore_index=True)
df
# Out:
#             A        B  C
# 0     6.75930  2.99840  0
# 1    -2.62890  3.97460  0
# 2     0.88878 -1.43350  1
# 3    -2.03500 -3.74210  0
# 4    -7.43160  0.86322  0
# ...       ...      ... ..
# 9995  5.01880 -0.28495  1
# 9996  7.23240 -0.24904  0
# 9997 -2.03320 -0.44094  1
# 9998 -4.49600 -1.99200  1
# 9999  2.50910  1.92650  0
#
# [10000 rows x 3 columns]

# %%
X = df[['A', 'B']]
y = df['C']
X
# Out:
#             A        B
# 0     6.75930  2.99840
# 1    -2.62890  3.97460
# 2     0.88878 -1.43350
# 3    -2.03500 -3.74210
# 4    -7.43160  0.86322
# ...       ...      ...
# 9995  5.01880 -0.28495
# 9996  7.23240 -0.24904
# 9997 -2.03320 -0.44094
# 9998 -4.49600 -1.99200
# 9999  2.50910  1.92650
#
# [10000 rows x 2 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
type(y_train)
y_test.size
# Out:
# 1000

# %%
# 5000 sample
rng = np.random.default_rng()
n = 5000

r = np.zeros([n,100], dtype = int)
XX = np.zeros([n, 2, 100])
r[:,0] = rng.choice(n, size = n, replace = True)
XX[:,:,0] = X[r[:,0], :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3789         try:
# -> 3790             return self._engine.get_loc(casted_key)
#    3791         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(array([4069, 4399, 2073, ...,  319, 4589, 2445]), slice(None, None, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipykernel_53823/3314039341.py in <module>
#       6 XX = np.zeros([n, 2, 100])
#       7 r[:,0] = rng.choice(n, size = n, replace = True)
# ----> 8 XX[:,:,0] = X[r[:,0], :]
#
# ...

# %%
# Jonas
rng = np.random.default_rng()
n = 5000
r = np.zeros ([n,100], dtype = int)
XX = np.zeros([n, 2, 100])
for i in range (100):
    r[:,i] = rng.choice(n, size = n, replace = True)
    XX[:,:,i] = X[ r[:,i],:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3789         try:
# -> 3790             return self._engine.get_loc(casted_key)
#    3791         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(array([3370, 4152, 4375, ..., 1015,  398, 3056]), slice(None, None, None))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipykernel_41364/1181722200.py in <module>
#       6 for i in range (100):
#       7     r[:,i] = rng.choice(n, size = n, replace = True)
# ----> 8     XX[:,:,i] = X[ r[:,i],:]
#
# ...
